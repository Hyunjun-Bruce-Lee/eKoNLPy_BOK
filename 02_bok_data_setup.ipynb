# %% [markdown]
# # 패키지/데이터 가져오기

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# 4/4AE2ecEn-UKViK5B1IGt8mkni9SqCVc6uJtBokn7JLK0b-cuf3-Ihkk
# Mounted at /content/drive

# %%
import pickle
import re

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
data_dir = '/content/drive/My Drive/2020NLP_Crawl/한국은행논문구현/'

# %% [markdown]
# # 뉴스

# %% [markdown]
# ## 연합뉴스

# %%
yonhap_df = pd.read_csv(data_dir + 'naver(연합뉴스).csv의 사본')

# %%
# 날짜에 들어간 불필요한 공백 제거
yonhap_df['time'] = yonhap_df['time'].str.strip()

# 날짜 datetime으로 변경
yonhap_df['time'] = pd.to_datetime(yonhap_df['time'])

# 날짜순 정렬
yonhap_df.sort_values(by='time', inplace=True, ignore_index=True)

yonhap_df
# Out:
#       media       time                                               body
# 0      연합뉴스 2005-05-01  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t작년동기.전...
# 1      연합뉴스 2005-05-01  ['\n\t', '\n\t', '\n\n', '\n', "\n\t\n\t(서울=연합...
# 2      연합뉴스 2005-05-02  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t거래량 4개...
# 3      연합뉴스 2005-05-02  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t(서울=연합...
# 4      연합뉴스 2005-05-02  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t(서울=연합...
# ...     ...        ...                                                ...
# 73770  연합뉴스 2017-12-31  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t"미·일 잠...
# 73771  연합뉴스 2017-12-31  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t', '1월...
# 73772  연합뉴스 2017-12-31  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t(서울=연합...
# 73773  연합뉴스 2017-12-31  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t', '  ...
# 73774  연합뉴스 2017-12-31  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\tGDP 성장...
#
# [73775 rows x 3 columns]

# %%
yonhap_df.dtypes
# Out:
# media            object
# time     datetime64[ns]
# body             object
# dtype: object

# %%
yonhap_df[yonhap_df['time'] == '2012.03.13.'].iloc[0,2]
# Out:
# "['\\n\\t', '\\n\\t', '\\n\\n', '\\n', '\\n\\t\\n\\t    (수원=연합뉴스) 최찬흥 기자 = 경기도는 일하기 좋은 기업 20곳과 일하기 좋은 공공기관 5곳을 선발한다고 13일 밝혔다.', '    도는 가족친화적 기업문화 확산을 위해 2010년부터 일하기 좋은 기업 인증제를 실시하고 있으며 지난해부터는 지식경제부와 함께 사업을 확대했다.', '    일하기 좋은 기업은 기업내 정보공유 정도, CEO와 근로자 간 신뢰지수, 자녀출산에 따른 지원, 직원 가족문화 활동, 양육 및 부양가족 지원, 탄력근무제 실시 등 가족친화시스템 구축 여부를 중점적으로 평가해 선발한다.', '    일하기 좋은 기업에 선정되면 중소기업육성자금 지원시 0.5%의 우대금리, 3년간의 지방세 세무조사 유예, 기술닥터사업 신청시 가점 부여 등 27개 항목의 인센티브가 제공된다. 공공기관에는 경영평가에 가산점을 준다.', '    신청대상은 도내에 사무소나 제조시설을 둔 창업 2년 이상의 기업이며 오는 28일까지 접수한다.', '    chan@yna.co.kr', ' ', '\\n\\n\\t', '\\n\\t']"

# %% [markdown]
# ### 저장/로드

# %%
# import pickle

# yonhap_file = data_dir + 'dataframes/yonhap_df.pkl'

# with open(yonhap_file, 'wb') as f:
#     pickle.dump(yonhap_df, f, pickle.HIGHEST_PROTOCOL)

# %%
import pickle

yonhap_file = data_dir + 'dataframes/yonhap_df.pkl'

with open(yonhap_file, 'rb') as f:
    yonhap_df = pickle.load(f)

yonhap_df
# Out:
#       media       time                                               body
# 0      연합뉴스 2005-05-01  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t작년동기.전...
# 1      연합뉴스 2005-05-01  ['\n\t', '\n\t', '\n\n', '\n', "\n\t\n\t(서울=연합...
# 2      연합뉴스 2005-05-02  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t거래량 4개...
# 3      연합뉴스 2005-05-02  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t(서울=연합...
# 4      연합뉴스 2005-05-02  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t(서울=연합...
# ...     ...        ...                                                ...
# 73770  연합뉴스 2017-12-31  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t"미·일 잠...
# 73771  연합뉴스 2017-12-31  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t', '1월...
# 73772  연합뉴스 2017-12-31  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t(서울=연합...
# 73773  연합뉴스 2017-12-31  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t', '  ...
# 73774  연합뉴스 2017-12-31  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\tGDP 성장...
#
# [73775 rows x 3 columns]

# %%
yonhap_df.dtypes
# Out:
# media            object
# time     datetime64[ns]
# body             object
# dtype: object

# %% [markdown]
# ## 연합인포맥스

# %%
yonhapinfo_df = pd.read_csv(data_dir + 'naver(연합인포맥스).csv의 사본')

yonhapinfo_df
# Out:
#         media           time                                               body
# 0      연합인포맥스   2013.03.04.   ['\r\n\t\r\n\t\t\r\n\t\t\r\n\t(서울=연합인포맥스) 오진우 ...
# 1      연합인포맥스   2013.01.09.   ['\r\n\t\r\n\t\t\r\n\t\t\r\n\t※다음은\xa0연합인포맥스가\...
# 2      연합인포맥스   2013.01.09.   ['\r\n\t\r\n\t\t\r\n\t\t\r\n\t(서울=연합인포맥스) 9일 서...
# 3      연합인포맥스   2013.02.04.   ['\r\n\t\r\n\t\t\r\n\t\t\r\n\t(서울=연합인포맥스) 권용욱 ...
# 4      연합인포맥스   2013.01.09.   ['\r\n\t\r\n\t\t\r\n\t\t\r\n\t(서울=연합인포맥스) 정선영 ...
# ...       ...            ...                                                ...
# 64673  연합인포맥스   2017.03.02.   ['\r\n\t\r\n\t\t\r\n\t\t\r\n\t(서울=연합인포맥스) 김성진 ...
# 64674  연합인포맥스   2017.03.02.   ['\r\n\t\r\n\t\t\r\n\t\t\r\n\t(서울=연합인포맥스) 이윤구 ...
# 64675  연합인포맥스   2017.03.02.   ['\r\n\t\r\n\t\t\r\n\t\t\r\n\t연준 3월 기준금리 인상 가능...
# 64676  연합인포맥스   2017.03.01.   ['\r\n\t\r\n\t\t\r\n\t\t\r\n\t차익매물 나오며 상승폭 둔화했...
# 64677  연합인포맥스   2017.03.02.   ['\r\n\t\r\n\t\t\r\n\t\t\r\n\t(뉴욕=연합인포맥스) 이종혁 ...
#
# ...

# %%
# 날짜에 들어간 불필요한 공백 제거
yonhapinfo_df['time'] = yonhapinfo_df['time'].str.strip()

# 날짜 datetime으로 변경
yonhapinfo_df['time'] = pd.to_datetime(yonhapinfo_df['time'])

# 날짜순 정렬
yonhapinfo_df.sort_values(by='time', inplace=True, ignore_index=True)

yonhapinfo_df
# Out:
#         media       time                                               body
# 0      연합인포맥스 2013-01-02  ['\r\n\t\r\n\t\t\r\n\t\t\r\n\t(서울=연합인포맥스) 이재헌 ...
# 1      연합인포맥스 2013-01-02  ['\r\n\t\r\n\t\t\r\n\t\t\r\n\t(서울=연합인포맥스) 권용욱 ...
# 2      연합인포맥스 2013-01-02  ['\r\n\t\r\n\t\t\r\n\t\t\r\n\t(서울=연합인포맥스) 권용욱 ...
# 3      연합인포맥스 2013-01-02  ['\r\n\t\r\n\t\t\r\n\t\t\r\n\t(서울=연합인포맥스) 이재헌 ...
# 4      연합인포맥스 2013-01-02  ['\r\n\t\r\n\t\t\r\n\t\t\r\n\t', ' ', '<사진설명 :...
# ...       ...        ...                                                ...
# 64673  연합인포맥스 2017-12-30  ['\r\n\t\r\n\t\t\r\n\t\t\r\n\t(뉴욕=연합뉴스) 신은실 연합...
# 64674  연합인포맥스 2017-12-30  ['\r\n\t\r\n\t\t\r\n\t\t\r\n\t(뉴욕=연합인포맥스) 이종혁 ...
# 64675  연합인포맥스 2017-12-30  ['\r\n\t\r\n\t\t\r\n\t\t\r\n\t(뉴욕=연합인포맥스) 이종혁 ...
# 64676  연합인포맥스 2017-12-30  ['\r\n\t\r\n\t\t\r\n\t\t\r\n\t(뉴욕=연합인포맥스) 신은실 ...
# 64677  연합인포맥스 2017-12-30  ['\r\n\t\r\n\t\t\r\n\t\t\r\n\t(뉴욕=연합인포맥스) 이종혁 ...
#
# [64678 rows x 3 columns]

# %%
yonhapinfo_df.dtypes
# Out:
# media            object
# time     datetime64[ns]
# body             object
# dtype: object

# %% [markdown]
# ### 저장/로드

# %%
# import pickle

# yonhapinfo_file = data_dir + 'dataframes/yonhapinfo_df.pkl'

# with open(yonhapinfo_file, 'wb') as f:
#     pickle.dump(yonhapinfo_df, f, pickle.HIGHEST_PROTOCOL)

# %%
import pickle

yonhapinfo_file = data_dir + 'dataframes/yonhapinfo_df.pkl'

with open(yonhapinfo_file, 'rb') as f:
    yonhapinfo_df = pickle.load(f)

yonhapinfo_df
# Out:
#         media       time                                               body
# 0      연합인포맥스 2013-01-02  ['\r\n\t\r\n\t\t\r\n\t\t\r\n\t(서울=연합인포맥스) 이재헌 ...
# 1      연합인포맥스 2013-01-02  ['\r\n\t\r\n\t\t\r\n\t\t\r\n\t(서울=연합인포맥스) 권용욱 ...
# 2      연합인포맥스 2013-01-02  ['\r\n\t\r\n\t\t\r\n\t\t\r\n\t(서울=연합인포맥스) 권용욱 ...
# 3      연합인포맥스 2013-01-02  ['\r\n\t\r\n\t\t\r\n\t\t\r\n\t(서울=연합인포맥스) 이재헌 ...
# 4      연합인포맥스 2013-01-02  ['\r\n\t\r\n\t\t\r\n\t\t\r\n\t', ' ', '<사진설명 :...
# ...       ...        ...                                                ...
# 64673  연합인포맥스 2017-12-30  ['\r\n\t\r\n\t\t\r\n\t\t\r\n\t(뉴욕=연합뉴스) 신은실 연합...
# 64674  연합인포맥스 2017-12-30  ['\r\n\t\r\n\t\t\r\n\t\t\r\n\t(뉴욕=연합인포맥스) 이종혁 ...
# 64675  연합인포맥스 2017-12-30  ['\r\n\t\r\n\t\t\r\n\t\t\r\n\t(뉴욕=연합인포맥스) 이종혁 ...
# 64676  연합인포맥스 2017-12-30  ['\r\n\t\r\n\t\t\r\n\t\t\r\n\t(뉴욕=연합인포맥스) 신은실 ...
# 64677  연합인포맥스 2017-12-30  ['\r\n\t\r\n\t\t\r\n\t\t\r\n\t(뉴욕=연합인포맥스) 이종혁 ...
#
# [64678 rows x 3 columns]

# %% [markdown]
# ## 이데일리

# %%
edaily_df = pd.read_csv(data_dir + 'naver(이데일리).csv의 사본')

# 날짜에 들어간 불필요한 공백 제거
edaily_df['time'] = edaily_df['time'].str.strip()

# 날짜 datetime으로 변경
edaily_df['time'] = pd.to_datetime(edaily_df['time'])

# 날짜순 정렬
edaily_df.sort_values(by='time', inplace=True, ignore_index=True)

edaily_df
# Out:
#        media       time                                               body
# 0       이데일리 2005-05-01  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t[edail...
# 1       이데일리 2005-05-01  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t[뉴욕=ed...
# 2       이데일리 2005-05-01  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t[edail...
# 3       이데일리 2005-05-01  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t[edail...
# 4       이데일리 2005-05-02  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t[edail...
# ...      ...        ...                                                ...
# 102000  이데일리        NaT  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t', '[이...
# 102001  이데일리        NaT  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t', '[이...
# 102002  이데일리        NaT  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t', '[이...
# 102003  이데일리        NaT  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t', '[이...
# 102004  이데일리        NaT  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t[이 기사는...
#
# [102005 rows x 3 columns]

# %% [markdown]
# ### datetime이 NaT로 처리된 row들 확인 후 제거

# %%
edaily_df.iloc[102004, 1]
# Out:
# NaT

# %%
# pd.isnull 써야 값이 NaT인 것 선택 가능
edaily_df[pd.isnull(edaily_df['time'])]
# Out:
#        media time                                               body
# 100401  이데일리  NaT  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t', '[이...
# 100402  이데일리  NaT  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t', '[이...
# 100403  이데일리  NaT  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t', '[이...
# 100404  이데일리  NaT  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t', '[이...
# 100405  이데일리  NaT  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t', '[이...
# ...      ...  ...                                                ...
# 102000  이데일리  NaT  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t', '[이...
# 102001  이데일리  NaT  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t', '[이...
# 102002  이데일리  NaT  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t', '[이...
# 102003  이데일리  NaT  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t', '[이...
# 102004  이데일리  NaT  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t[이 기사는...
#
# [1604 rows x 3 columns]

# %%
# 값이 NaT인 것 제외하고 선택
edaily_df = edaily_df[~(pd.isnull(edaily_df['time']))]

edaily_df
# Out:
#        media       time                                               body
# 0       이데일리 2005-05-01  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t[edail...
# 1       이데일리 2005-05-01  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t[뉴욕=ed...
# 2       이데일리 2005-05-01  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t[edail...
# 3       이데일리 2005-05-01  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t[edail...
# 4       이데일리 2005-05-02  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t[edail...
# ...      ...        ...                                                ...
# 100396  이데일리 2017-12-30  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t', '[이...
# 100397  이데일리 2017-12-30  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t[뉴스속보팀...
# 100398  이데일리 2017-12-30  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t', '[이...
# 100399  이데일리 2017-12-30  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t', '[이...
# 100400  이데일리 2017-12-31  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t', '[이...
#
# [100401 rows x 3 columns]

# %% [markdown]
# ### 저장/로드

# %%
# import pickle

# edaily_file = data_dir + 'dataframes/edaily_df.pkl'

# with open(edaily_file, 'wb') as f:
#     pickle.dump(edaily_df, f, pickle.HIGHEST_PROTOCOL)

# %%
import pickle

edaily_file = data_dir + 'dataframes/edaily_df.pkl'

with open(edaily_file, 'rb') as f:
    edaily_df = pickle.load(f)

edaily_df
# Out:
#        media       time                                               body
# 0       이데일리 2005-05-01  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t[edail...
# 1       이데일리 2005-05-01  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t[뉴욕=ed...
# 2       이데일리 2005-05-01  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t[edail...
# 3       이데일리 2005-05-01  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t[edail...
# 4       이데일리 2005-05-02  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t[edail...
# ...      ...        ...                                                ...
# 100396  이데일리 2017-12-30  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t', '[이...
# 100397  이데일리 2017-12-30  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t[뉴스속보팀...
# 100398  이데일리 2017-12-30  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t', '[이...
# 100399  이데일리 2017-12-30  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t', '[이...
# 100400  이데일리 2017-12-31  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t', '[이...
#
# [100401 rows x 3 columns]

# %%
edaily_df.dtypes
# Out:
# media            object
# time     datetime64[ns]
# body             object
# dtype: object

# %% [markdown]
# # 금리

# %% [markdown]
# ## 기준금리

# %%
baserate_file = data_dir + '4_BASE_RATE.txt'
baserate_df = pd.read_csv(baserate_file, sep='\t', header=None)
baserate_df
# Out:
#        0        1     2
# 0   2020  05월 28일  0.50
# 1   2020  03월 17일  0.75
# 2   2019  10월 16일  1.25
# 3   2019  07월 18일  1.50
# 4   2018  11월 30일  1.75
# 5   2017  11월 30일  1.50
# 6   2016  06월 09일  1.25
# 7   2015  06월 11일  1.50
# 8   2015  03월 12일  1.75
# 9   2014  10월 15일  2.00
# 10  2014  08월 14일  2.25
# 11  2013  05월 09일  2.50
# 12  2012  10월 11일  2.75
# 13  2012  07월 12일  3.00
# 14  2011  06월 10일  3.25
# 15  2011  03월 10일  3.00
# 16  2011  01월 13일  2.75
# 17  2010  11월 16일  2.50
# 18  2010  07월 09일  2.25
# 19  2009  02월 12일  2.00
# 20  2009  01월 09일  2.50
# 21  2008  12월 11일  3.00
# 22  2008  11월 07일  4.00
# 23  2008  10월 27일  4.25
# 24  2008  10월 09일  5.00
# 25  2008  08월 07일  5.25
# 26  2007  08월 09일  5.00
# 27  2007  07월 12일  4.75
# 28  2006  08월 10일  4.50
# 29  2006  06월 08일  4.25
# 30  2006  02월 09일  4.00
# 31  2005  12월 08일  3.75
# 32  2005  10월 11일  3.50
# 33  2004  11월 11일  3.25
# 34  2004  08월 12일  3.50
# 35  2003  07월 10일  3.75
# 36  2003  05월 13일  4.00
# ...

# %%
# column 이름 변경
baserate_df.columns = ['year', 'month_date', 'base_rate']

baserate_df
# Out:
#     year month_date  base_rate
# 0   2020    05월 28일       0.50
# 1   2020    03월 17일       0.75
# 2   2019    10월 16일       1.25
# 3   2019    07월 18일       1.50
# 4   2018    11월 30일       1.75
# 5   2017    11월 30일       1.50
# 6   2016    06월 09일       1.25
# 7   2015    06월 11일       1.50
# 8   2015    03월 12일       1.75
# 9   2014    10월 15일       2.00
# 10  2014    08월 14일       2.25
# 11  2013    05월 09일       2.50
# 12  2012    10월 11일       2.75
# 13  2012    07월 12일       3.00
# 14  2011    06월 10일       3.25
# 15  2011    03월 10일       3.00
# 16  2011    01월 13일       2.75
# 17  2010    11월 16일       2.50
# 18  2010    07월 09일       2.25
# 19  2009    02월 12일       2.00
# 20  2009    01월 09일       2.50
# 21  2008    12월 11일       3.00
# 22  2008    11월 07일       4.00
# 23  2008    10월 27일       4.25
# 24  2008    10월 09일       5.00
# 25  2008    08월 07일       5.25
# 26  2007    08월 09일       5.00
# 27  2007    07월 12일       4.75
# 28  2006    08월 10일       4.50
# ...

# %%
import re
p = re.compile('\d+')   # 숫자 묶음 추출하는 정규표현식

def get_baserate_time(row):
    # 연: 그대로 사용
    year = row.year
    # 월, 일: 예) '02월 08일' -> ['02', '08'] 각각 month, date에 저장
    month, date = p.findall(row.month_date) 

    # 연월일 이어붙이고 datetime으로 변경
    time = pd.to_datetime('{}-{}-{}'.format(year, month, date))

    return time

# %%
# get_baserate_time() 적용, axis=1 꼭 써야 row 단위로 잘 적용됨
baserate_df['time'] = baserate_df.apply(lambda x: get_baserate_time(x), axis=1)

# 날짜순 정렬
baserate_df.sort_values(by='time', inplace=True, ignore_index=True)

# 날짜, 금리 column만 선택
baserate_df = baserate_df[['time', 'base_rate']]

baserate_df
# Out:
#          time  base_rate
# 0  1999-05-06       4.75
# 1  2000-02-10       5.00
# 2  2000-10-05       5.25
# 3  2001-02-08       5.00
# 4  2001-07-05       4.75
# 5  2001-08-09       4.50
# 6  2001-09-19       4.00
# 7  2002-05-07       4.25
# 8  2003-05-13       4.00
# 9  2003-07-10       3.75
# 10 2004-08-12       3.50
# 11 2004-11-11       3.25
# 12 2005-10-11       3.50
# 13 2005-12-08       3.75
# 14 2006-02-09       4.00
# 15 2006-06-08       4.25
# 16 2006-08-10       4.50
# 17 2007-07-12       4.75
# 18 2007-08-09       5.00
# 19 2008-08-07       5.25
# 20 2008-10-09       5.00
# 21 2008-10-27       4.25
# 22 2008-11-07       4.00
# 23 2008-12-11       3.00
# 24 2009-01-09       2.50
# 25 2009-02-12       2.00
# 26 2010-07-09       2.25
# 27 2010-11-16       2.50
# 28 2011-01-13       2.75
# 29 2011-03-10       3.00
# 30 2011-06-10       3.25
# 31 2012-07-12       3.00
# 32 2012-10-11       2.75
# 33 2013-05-09       2.50
# 34 2014-08-14       2.25
# 35 2014-10-15       2.00
# ...

# %% [markdown]
# ### 빈 날짜에 해당하는 금리 값 채우기

# %%
# 날짜를 index로 설정
baserate_df = baserate_df.set_index('time')

# 범위 내의 모든 날짜를 생성
idx = pd.date_range('2005-05-01', '2020-05-28')

# ffill: 새로운 유효값이 나올 때까지 이전 유효값으로 이후의 비유효값을 채움
baserate_df = baserate_df.reindex(idx, method='ffill')

# index 숫자로 재설정
baserate_df.reset_index(inplace=True)

# 날짜 column 'time'으로 재명명
baserate_df.rename(columns={'index': 'time'}, inplace=True)

baserate_df
# Out:
#            time  base_rate
# 0    2005-05-01       3.25
# 1    2005-05-02       3.25
# 2    2005-05-03       3.25
# 3    2005-05-04       3.25
# 4    2005-05-05       3.25
# ...         ...        ...
# 5502 2020-05-24       0.75
# 5503 2020-05-25       0.75
# 5504 2020-05-26       0.75
# 5505 2020-05-27       0.75
# 5506 2020-05-28       0.50
#
# [5507 rows x 2 columns]

# %% [markdown]
# ### 저장/로드

# %%
# import pickle

# baserate_file = data_dir + 'dataframes/baserate_df.pkl'

# with open(baserate_file, 'wb') as f:
#     pickle.dump(baserate_df, f, pickle.HIGHEST_PROTOCOL)

# %%
import pickle

baserate_file = data_dir + 'dataframes/baserate_df.pkl'

with open(baserate_file, 'rb') as f:
    baserate_df = pickle.load(f)

baserate_df
# Out:
#            time  base_rate
# 0    2005-05-01       3.25
# 1    2005-05-02       3.25
# 2    2005-05-03       3.25
# 3    2005-05-04       3.25
# 4    2005-05-05       3.25
# ...         ...        ...
# 5502 2020-05-24       0.75
# 5503 2020-05-25       0.75
# 5504 2020-05-26       0.75
# 5505 2020-05-27       0.75
# 5506 2020-05-28       0.50
#
# [5507 rows x 2 columns]

# %%
baserate_df.dtypes
# Out:
# time         datetime64[ns]
# base_rate           float64
# dtype: object

# %% [markdown]
# ## 콜금리

# %%
callrate_file = data_dir + '5_CALL_RATE.csv'
callrate_df = pd.read_csv(callrate_file, header=None)
callrate_df
# Out:
#                0     1         2
# 0     2020.08.31  0.55  + 12.24%
# 1     2020.08.28  0.49    -2.00%
# 2     2020.08.27  0.50    -5.66%
# 3     2020.08.26  0.53   + 1.92%
# 4     2020.08.25  0.52    -1.89%
# ...          ...   ...       ...
# 4867  2001.01.12  5.33   + 0.19%
# 4868  2001.01.11  5.32     0.00%
# 4869  2001.01.10  5.32   + 0.38%
# 4870  2001.01.09  5.30    -0.38%
# 4871  2001.01.08  5.32    -0.37%
#
# [4872 rows x 3 columns]

# %%
# column 이름 변경
callrate_df.columns = ['time', 'call_rate', 'change']

# 날짜 datetime으로 변경
callrate_df['time'] = pd.to_datetime(callrate_df['time'])

# 날짜순 정렬
callrate_df.sort_values(by='time', inplace=True, ignore_index=True)

callrate_df
# Out:
#            time  call_rate    change
# 0    2001-01-08       5.32    -0.37%
# 1    2001-01-09       5.30    -0.38%
# 2    2001-01-10       5.32   + 0.38%
# 3    2001-01-11       5.32     0.00%
# 4    2001-01-12       5.33   + 0.19%
# ...         ...        ...       ...
# 4867 2020-08-25       0.52    -1.89%
# 4868 2020-08-26       0.53   + 1.92%
# 4869 2020-08-27       0.50    -5.66%
# 4870 2020-08-28       0.49    -2.00%
# 4871 2020-08-31       0.55  + 12.24%
#
# [4872 rows x 3 columns]

# %% [markdown]
# ### 빈 날짜에 해당하는 금리 값 채우기

# %%
# 날짜를 index로 설정
callrate_df.set_index('time', inplace=True)

# 범위 내의 모든 날짜를 생성, 2005년 5월 이전 데이터도 포함
idx = pd.date_range('2005-01-01', '2020-08-31')

# 디폴트인 NaN으로 값을 일단 채움
callrate_df = callrate_df.reindex(idx)

callrate_df
# Out:
#             call_rate    change
# 2005-01-01        NaN       NaN
# 2005-01-02        NaN       NaN
# 2005-01-03       3.27    -0.61%
# 2005-01-04       3.27     0.00%
# 2005-01-05       3.28   + 0.31%
# ...               ...       ...
# 2020-08-27       0.50    -5.66%
# 2020-08-28       0.49    -2.00%
# 2020-08-29        NaN       NaN
# 2020-08-30        NaN       NaN
# 2020-08-31       0.55  + 12.24%
#
# [5722 rows x 2 columns]

# %%
# 콜금리는 ffill로 채움
callrate_df['call_rate'].ffill(inplace=True)

callrate_df
# Out:
#             call_rate    change
# 2005-01-01        NaN       NaN
# 2005-01-02        NaN       NaN
# 2005-01-03       3.27    -0.61%
# 2005-01-04       3.27     0.00%
# 2005-01-05       3.28   + 0.31%
# ...               ...       ...
# 2020-08-27       0.50    -5.66%
# 2020-08-28       0.49    -2.00%
# 2020-08-29       0.49       NaN
# 2020-08-30       0.49       NaN
# 2020-08-31       0.55  + 12.24%
#
# [5722 rows x 2 columns]

# %%
# 변화는 '0.00%'로 채움
callrate_df['change'].fillna(value='0.00%', inplace=True)

callrate_df
# Out:
#             call_rate    change
# 2005-01-01        NaN     0.00%
# 2005-01-02        NaN     0.00%
# 2005-01-03       3.27    -0.61%
# 2005-01-04       3.27     0.00%
# 2005-01-05       3.28   + 0.31%
# ...               ...       ...
# 2020-08-27       0.50    -5.66%
# 2020-08-28       0.49    -2.00%
# 2020-08-29       0.49     0.00%
# 2020-08-30       0.49     0.00%
# 2020-08-31       0.55  + 12.24%
#
# [5722 rows x 2 columns]

# %%
# index 숫자로 재설정
callrate_df.reset_index(inplace=True)

# 날짜 column 'time'으로 재명명
callrate_df.rename(columns={'index': 'time'}, inplace=True)

# 2005-05-01 이후 데이터만 남기고 인덱스 재설정
callrate_df = callrate_df[callrate_df['time'] >= pd.to_datetime('2005-05-01')].reset_index(drop=True)

callrate_df
# Out:
#            time  call_rate    change
# 0    2005-05-01       3.29     0.00%
# 1    2005-05-02       3.29     0.00%
# 2    2005-05-03       3.30   + 0.30%
# 3    2005-05-04       3.21    -2.73%
# 4    2005-05-05       3.21     0.00%
# ...         ...        ...       ...
# 5597 2020-08-27       0.50    -5.66%
# 5598 2020-08-28       0.49    -2.00%
# 5599 2020-08-29       0.49     0.00%
# 5600 2020-08-30       0.49     0.00%
# 5601 2020-08-31       0.55  + 12.24%
#
# [5602 rows x 3 columns]

# %% [markdown]
# ### 저장/로드

# %%
# import pickle

# callrate_file = data_dir + 'dataframes/callrate_df.pkl'

# with open(callrate_file, 'wb') as f:
#     pickle.dump(callrate_df, f, pickle.HIGHEST_PROTOCOL)

# %%
import pickle

callrate_file = data_dir + 'dataframes/callrate_df.pkl'

with open(callrate_file, 'rb') as f:
    callrate_df = pickle.load(f)

callrate_df
# Out:
#            time  call_rate    change
# 0    2005-05-01       3.29     0.00%
# 1    2005-05-02       3.29     0.00%
# 2    2005-05-03       3.30   + 0.30%
# 3    2005-05-04       3.21    -2.73%
# 4    2005-05-05       3.21     0.00%
# ...         ...        ...       ...
# 5597 2020-08-27       0.50    -5.66%
# 5598 2020-08-28       0.49    -2.00%
# 5599 2020-08-29       0.49     0.00%
# 5600 2020-08-30       0.49     0.00%
# 5601 2020-08-31       0.55  + 12.24%
#
# [5602 rows x 3 columns]

# %%
callrate_df.dtypes
# Out:
# time         datetime64[ns]
# call_rate           float64
# change               object
# dtype: object

# %% [markdown]
# # 채권분석 보고서

# %%
bond_file = data_dir + 'bond_report.xlsx'

bond_df = pd.read_excel(bond_file)

bond_df
# Out:
#             date                                           contents
# 0     2020.09.02  2013년 0월 0일          천 리 길도 한 걸음부터 Issue Comme...
# 1     2020.09.02              2020. 9. 1 정부가 내년도 예산을 555.8조원으로 발...
# 2     2020.09.01  Microsoft Word - 2020083117554824.docx  8  글로벌...
# 3     2020.09.01       2020년 8월 31일 국고채 시장 약세, 한국은행 매입으로 해결하기 어렵...
# 4     2020.08.31       Compliance Notice   당사는 동 자료를 기관투자자 또는 제...
# ...          ...                                                ...
# 3782  2008.04.21  Microsoft Word - 920_0421_Fixed Income Weekly....
# 3783  2008.04.14  Microsoft Word - Fixedincome0414.doc    4월 금통위...
# 3784  2008.04.07  Microsoft Word - 0407.docFixed Income Weekly 2...
# 3785  2008.04.07  Microsoft Word - 0407.docFixed Income Weekly 2...
# 3786  2008.04.01  ㅎㅎㅎ2008_04  월간채권투자채 권 시 장 전 망금 융 시 장 차 트 북對應과 ...
#
# [3787 rows x 2 columns]

# %%
# column 이름 변경: 'date'을 다른 데이터들에 맞게 'time'으로 변경
bond_df.columns = ['time', 'contents']

# 날짜를 datetime으로 변경
bond_df['time'] = pd.to_datetime(bond_df['time'])

# 날짜순 정렬
bond_df.sort_values(by='time', inplace=True, ignore_index=True)

bond_df
# Out:
#            time                                           contents
# 0    2008-04-01  ㅎㅎㅎ2008_04  월간채권투자채 권 시 장 전 망금 융 시 장 차 트 북對應과 ...
# 1    2008-04-07  Microsoft Word - 0407.docFixed Income Weekly 2...
# 2    2008-04-07  Microsoft Word - 0407.docFixed Income Weekly 2...
# 3    2008-04-14  Microsoft Word - Fixedincome0414.doc    4월 금통위...
# 4    2008-04-21  Microsoft Word - 920_0421_Fixed Income Weekly....
# ...         ...                                                ...
# 3782 2020-08-31       Compliance Notice   당사는 동 자료를 기관투자자 또는 제...
# 3783 2020-09-01       2020년 8월 31일 국고채 시장 약세, 한국은행 매입으로 해결하기 어렵...
# 3784 2020-09-01  Microsoft Word - 2020083117554824.docx  8  글로벌...
# 3785 2020-09-02              2020. 9. 1 정부가 내년도 예산을 555.8조원으로 발...
# 3786 2020-09-02  2013년 0월 0일          천 리 길도 한 걸음부터 Issue Comme...
#
# [3787 rows x 2 columns]

# %% [markdown]
# ## 저장/로드

# %%
# import pickle

# bond_file = data_dir + 'dataframes/bond_df.pkl'

# with open(bond_file, 'wb') as f:
#     pickle.dump(bond_df, f, pickle.HIGHEST_PROTOCOL)

# %%
import pickle

bond_file = data_dir + 'dataframes/bond_df.pkl'

with open(bond_file, 'rb') as f:
    bond_df = pickle.load(f)

# %%
bond_df
# Out:
#            time                                           contents
# 0    2008-04-01  ㅎㅎㅎ2008_04  월간채권투자채 권 시 장 전 망금 융 시 장 차 트 북對應과 ...
# 1    2008-04-07  Microsoft Word - 0407.docFixed Income Weekly 2...
# 2    2008-04-07  Microsoft Word - 0407.docFixed Income Weekly 2...
# 3    2008-04-14  Microsoft Word - Fixedincome0414.doc    4월 금통위...
# 4    2008-04-21  Microsoft Word - 920_0421_Fixed Income Weekly....
# ...         ...                                                ...
# 3782 2020-08-31       Compliance Notice   당사는 동 자료를 기관투자자 또는 제...
# 3783 2020-09-01       2020년 8월 31일 국고채 시장 약세, 한국은행 매입으로 해결하기 어렵...
# 3784 2020-09-01  Microsoft Word - 2020083117554824.docx  8  글로벌...
# 3785 2020-09-02              2020. 9. 1 정부가 내년도 예산을 555.8조원으로 발...
# 3786 2020-09-02  2013년 0월 0일          천 리 길도 한 걸음부터 Issue Comme...
#
# [3787 rows x 2 columns]

# %%
bond_df.dtypes
# Out:
# time        datetime64[ns]
# contents            object
# dtype: object

# %% [markdown]
# # 금융통화위원회 의사록

# %%
mpd_file = '/content/drive/My Drive/2020NLP_Crawl/' + 'bok_mpd/bok_minute_data.csv'

mpd_df = pd.read_csv(mpd_file, header=None)
mpd_df.head()
# Out:
#                                        0                                                  1
# 0   금융통화위원회 의사록(2017년도 제23차)(2017.12.7.)     2017년도 제23차\n금융통화위원회(정기) 의사록\n   한 국    은 행...
# 1  금융통화위원회 의사록(2017년도 제22차)(2017.11.30.)     2017년도 제22차\n금융통화위원회(정기) 의사록\n   한 국    은 행...
# 2   금융통화위원회 의사록(2017년도 제21차)(2017.11.9.)     2017년도 제21차\n금융통화위원회(정기) 의사록\n   한 국    은 행...
# 3  금융통화위원회 의사록(2017년도 제19차)(2017.10.19.)     2017년도 제19차\n금융통화위원회(정기) 의사록\n   한 국    은 행...
# 4   금융통화위원회 의사록(2017년도 제18차)(2017.9.21.)     2017년도 제18차\n금융통화위원회(정기) 의사록\n   한 국    은 행...

# %%
mpd_df.columns
# Out:
# Int64Index([0, 1], dtype='int64')

# %%
# column 이름 변경
mpd_df.columns = ['title', 'content']

mpd_df.head()
# Out:
#                                    title                                            content
# 0   금융통화위원회 의사록(2017년도 제23차)(2017.12.7.)     2017년도 제23차\n금융통화위원회(정기) 의사록\n   한 국    은 행...
# 1  금융통화위원회 의사록(2017년도 제22차)(2017.11.30.)     2017년도 제22차\n금융통화위원회(정기) 의사록\n   한 국    은 행...
# 2   금융통화위원회 의사록(2017년도 제21차)(2017.11.9.)     2017년도 제21차\n금융통화위원회(정기) 의사록\n   한 국    은 행...
# 3  금융통화위원회 의사록(2017년도 제19차)(2017.10.19.)     2017년도 제19차\n금융통화위원회(정기) 의사록\n   한 국    은 행...
# 4   금융통화위원회 의사록(2017년도 제18차)(2017.9.21.)     2017년도 제18차\n금융통화위원회(정기) 의사록\n   한 국    은 행...

# %% [markdown]
# ## 날짜 column 생성

# %%
import re
# 괄호 안 텍스트만 추출하는 정규표현식
p = re.compile(r'\((.*?)\)')

def get_mpd_date(title):
    # 의사록 제목에서 괄호 안 텍스트를 추출하고 그 중 마지막에 해당하는 날짜 추출
    date = p.findall(title)[-1]
    
    # 날짜 값이 존재하면 datetime으로 변경
    if date:
        return pd.to_datetime(date)

    # 예외
    else:
        print('No date exists for {}!'.format(title))

# %%
# 의사록 제목에 get_mpd_date()를 적용해 날짜 추출하고 새 column에 저장
mpd_df['time'] = mpd_df['title'].apply(lambda x: get_mpd_date(x))
mpd_df.sort_values(by='time', inplace=True, ignore_index=True)

mpd_df
# Out:
#                                                  title  ...       time
# 0    금융통화위원회 의사록(2005년도 제10차)(2...  ... 2005-05-12
# 1                   금융통화위원회 의사록(2005년도 제12차)(2005.6.9)  ... 2005-06-09
# 2                  금융통화위원회 의사록(2005년도 제13차)(2005.6.23)  ... 2005-06-23
# 3                   금융통화위원회 의사록(2005년도 제14차)(2005.7.7)  ... 2005-07-07
# 4                  금융통화위원회 의사록(2005년도 제17차)(2005.8.11)  ... 2005-08-11
# ..                                                 ...  ...        ...
# 258               금융통화위원회 의사록(2017년도 제18차)(2017.9.21.)  ... 2017-09-21
# 259              금융통화위원회 의사록(2017년도 제19차)(2017.10.19.)  ... 2017-10-19
# 260               금융통화위원회 의사록(2017년도 제21차)(2017.11.9.)  ... 2017-11-09
# 261              금융통화위원회 의사록(2017년도 제22차)(2017.11.30.)  ... 2017-11-30
# 262               금융통화위원회 의사록(2017년도 제23차)(2017.12.7.)  ... 2017-12-07
#
# [263 rows x 3 columns]

# %% [markdown]
# ## 강사님이 주신 섹션 분리 코드 적용

# %%
def tidy_sentences(section):
    sentence_enders = re.compile(r'((?<=[함음됨임봄짐움])(\s*\n|\.|;)|(?<=다)\.)\s*')
    splits = list((m.start(), m.end()) for m in re.finditer(sentence_enders, section))
    starts = [0] + [i[1] for i in splits]
    ends = [i[0] for i in splits]
    sentences = [section[start:end] for start, end in zip(starts[:-1], ends)]
    for i, s in enumerate(sentences):
        sentences[i] = (s.replace('\n', ' ').replace(' ', ' ')) + '.'

    text = '\n'.join(sentences) if len(sentences) > 0 else ''
    return sentences, text

# %%
import re 

def preprocess_minutes(minutes):

    pos = re.search('(.?국내외\s?경제\s?동향.?과 관련하여,?|\(가\).+경제전망.*|\(가\) 국내외 경제동향 및 평가)\n?\s*일부 위원은', minutes, re.MULTILINE)
    s1 = pos.start() if pos else -1
    pos = re.search('(.?외환.?국제금융\s?동향.?과 관련하여.*|\(나\) 외환.국제금융\s?(및 금융시장)?\s?동향)\n?\s*(일부 위원은|대부분의 위원들은)', minutes,re.MULTILINE)
    s2 = pos.start() if pos else -1
    pos = re.search('(.?금융시장\s?동향.?과 관련하여,?|\(다\) 금융시장\s?동향)\n?\s*일부 위원은', minutes, re.MULTILINE)
    s3 = pos.start() if pos else -1
    pos = re.search('((\((다|라)\) )?.?통화정책\s?방향.?에 관한 토론,?|이상과 같은 의견\s?교환을 바탕으로.*통화정책\s?방향.*에.*토론.*)\n?', minutes,re.MULTILINE)
    s4 = pos.start() if pos else -1
    pos = re.search('(\(4\) 정부측 열석자 발언.*)\n?', minutes, re.MULTILINE)
    s5 = pos.start() if pos else -1
    pos = re.search('(\(.*\) 한국은행 기준금리 결정에 관한 위원별 의견\s?개진|이상과 같은 토론에 이어 .* 관한 위원별 의견개진이 있었음.*)\n?', minutes,re.MULTILINE)
    s6 = pos.start() if pos else -1
    positer = re.finditer('(\(\s?.*\s?\) ()(심의결과|토의결론))\n?', minutes, re.MULTILINE)
    s7 = [pos.start() for pos in positer if pos.start() > s6]
    s7 = s7[0] if s7 else -1

    # 국내외 경제동향
    bos = s1
    eos = s2
    section = minutes[bos:eos] if bos >= 0 or eos >= 0 else ''
    pos = re.search('(일부|대부분의) 위원들?은', section, re.MULTILINE)
    bos = pos.start() if pos else -1
    section = section[bos:] if bos >= 0 else section
    section1, section1_txt = tidy_sentences(section)

    # 외환․국제금융 동향
    bos = s2
    eos = s3 if s3 >= 0 else s4
    section = minutes[bos:eos] if bos >= 0 or eos >= 0 else ''
    pos = re.search('(일부|대부분의) 위원들?은', section, re.MULTILINE)
    bos = pos.start() if pos else -1
    section = section[bos:] if bos >= 0 else section
    section2, section2_txt = tidy_sentences(section)
    #print(section)

    # 금융시장 동향
    bos = s3
    eos = s4
    section = minutes[bos:eos] if bos >= 0 or eos >= 0 else ''
    pos = re.search('(일부|대부분의) 위원들?은', section, re.MULTILINE)
    bos = pos.start() if pos else -1
    section = section[bos:] if bos >= 0 else section
    section3, section3_txt = tidy_sentences(section)

    # 통화정책방향
    bos = s4
    eos = s5 if s5 >= 0 else s6 if s6 >= 0 else s7
    section = minutes[bos:eos] if bos >= 0 or eos >= 0 else ''
    pos = re.search('(일부|대부분의) 위원들?은', section, re.MULTILINE)
    bos = pos.start() if pos else -1
    section = section[bos:] if bos >= 0 else section
    section4, section4_txt = tidy_sentences(section)

    # 위원별 의견 개진
    bos = s6
    eos = s7
    section = minutes[bos:eos] if bos >= 0 or eos >= 0 else ''
    pos = re.search('(일부|대부분의) 위원들?은', section, re.MULTILINE)
    bos = pos.start() if pos else -1
    section = section[bos:] if bos >= 0 else section
    section5, section5_txt = tidy_sentences(section)

    # 정부측 열석자 발언
    bos = s5
    eos = s6
    section = minutes[bos:eos] if bos >= 0 or eos >= 0 else ''
    pos = re.search('정부측 열석자 발언', section, re.MULTILINE)
    bos = pos.end() + 1 if pos else -1
    section = section[bos:] if bos >= 0 else section
    section6, section6_txt = tidy_sentences(section)

    sections = ['Economic Situation', 'Foreign Currency', 'Financial Markets',
                'Monetary Policy', 'Participants’ Views', 'Government’s View']
    section_texts = (section1, section2, section3, section4, section5, section6)


    return sections, section_texts

# %%
content_test = mpd_df.iloc[0,1]
content_test
# Out:
# '                     金融通貨委員會 議事錄\n2005년도 제10차 회의\n1. 일  시   2005년 5월 12일 (목)\n2. 장  소   금융통화위원회 회의실\n3. 출석위원     박  승 의 장 (총 재)\n              김태동 위원\n              이 성 태 위 원 (부총재)\n              김종창 위원\n              강문수 위원\n              이덕훈 위원\n              이성남 위원\n4. 결석위원     없   음\n5. 참 여 자   이 상 용 감사         정 규 영 부총재보\n        정 방 우 부총재보         박 재 환 부총재보\n        김 수 명 부총재보         이 영 균 부총재보\n\n\n         정 해 왕 금융경제연구원장   김 재 천 조사국장\n         이 주 열 정책기획국장   김 수 호 금융시장국장\n         이 광 주 국제국장    정 이 모 금융통화위원회실장\n         이 광 준 공보실장\n6. 회의경과\n   〈의안 제17호 ― 통화정책방향〉\n    (１) 전일 개최된 동향보고회의에서 조사국장이 보고 제54호 - ｢국내외 경제동향｣,\n국제국장이 보고 제55호 - ｢외환․국제금융 동향｣, 그리고 금융시장국장이 보고 제56호\n-｢금융시장 동향｣에 대하여 보고하였음(보고내용: 별첨)\n    (２) 본회의에서는 의장이 ｢한국은행법｣ 제28조에 의거하여 의안 제17호 - ｢통화정\n책방향｣을 상정하였음\n    (３) 위원 토의내용\n      ｢국내외 경제동향｣과 관련하여, 일부 위원은 지난해 풍작에 따른 효과와 금년초\n담배가격 인상에 따른 생산 감소 등 특수요인을 제외하면 금년 1/4분기에도 작년 4/4분\n기와 비슷한 경제성장세가 유지되고 있는 것으로 보인다는 견해를 밝혔음\n\n\n   동 위원은 건설투자의 선행지표인 건축허가면적과 국내 건설수주액이 기성이나\n실제 건설
# ...

# %%
preprocess_minutes(content_test)
# Out:
# (['Economic Situation',
#   'Foreign Currency',
#   'Financial Markets',
#   'Monetary Policy',
#   'Participants’ Views',
#   'Government’s View'],
#  (['일부 위원은 지난해 풍작에 따른 효과와 금년초 담배가격 인상에 따른 생산 감소 등 특수요인을 제외하면 금년 1/4분기에도 작년 4/4분 기와 비슷한 경제성장세가 유지되고 있는 것으로 보인다는 견해를 밝혔음.',
#    '동 위원은 건설투자의 선행지표인 건축허가면적과 국내 건설수주액이 기성이나 실제 건설투자로 나타나는 데 걸리는 시간을 감안할 때 2003년 3/4분기부터 2004년 3/ 4분기까지 이어진 건축허가면적과 국내 건설수주실적의 마이너스 성장세가 금년 하반 기 건설투자의 부진으로 나타나지는 않을지 물었음.',
#    '이에 대해 관련부서에서는 지난해 3/4분기까지 건설수주실적이 저조했던 데 따 른 영향이 금년 하반기까지 계속되기는 하겠으나 새로운 요인으로서 작년 4/4분기 이 후 건설수주실적이 호전되어 실제 착공으로 이어지고 있는 물량과 정부 종합투자계획 이 플러스 요인으로 작용할 것임을 감안하면 하반기경에는 건설투자가 부진에서 벗어 나 점차 개선될 것으로 보인다고 답변하였음.',
#    '또한 동 위원은 수출물량이 가격요인보다는 해외 수요요인에 의해 주로 결정된 다는 분석결과와 관련하여 동 분석에서 대상으로 한 기간이 환율 변동이 심했던 외환 위기 전후를 포함하고 있는 데다 국제시장에서 동질의 제품끼리 벌이는 치열한 경쟁에 있어서는 가격이 물량에 미치는 영향력이 상당할 것임을 감안할 때 환율 하락이 수출 에 미치는 영향이 과소평가된 것은 아닌지 물었음.',
# ...

# %%
mpd_df['content_sep'] = mpd_df['content'].apply(lambda x: preprocess_minutes(x))
mpd_df.head()
# Out:
#                                                title  ...                                        content_sep
# 0  금융통화위원회 의사록(2005년도 제10차)(2...  ...  ([Economic Situation, Foreign Currency, Financ...
# 1                 금융통화위원회 의사록(2005년도 제12차)(2005.6.9)  ...  ([Economic Situation, Foreign Currency, Financ...
# 2                금융통화위원회 의사록(2005년도 제13차)(2005.6.23)  ...  ([Economic Situation, Foreign Currency, Financ...
# 3                 금융통화위원회 의사록(2005년도 제14차)(2005.7.7)  ...  ([Economic Situation, Foreign Currency, Financ...
# 4                금융통화위원회 의사록(2005년도 제17차)(2005.8.11)  ...  ([Economic Situation, Foreign Currency, Financ...
#
# [5 rows x 4 columns]

# %%
mpd_df.iloc[0,3]
# Out:
# (['Economic Situation',
#   'Foreign Currency',
#   'Financial Markets',
#   'Monetary Policy',
#   'Participants’ Views',
#   'Government’s View'],
#  (['일부 위원은 지난해 풍작에 따른 효과와 금년초 담배가격 인상에 따른 생산 감소 등 특수요인을 제외하면 금년 1/4분기에도 작년 4/4분 기와 비슷한 경제성장세가 유지되고 있는 것으로 보인다는 견해를 밝혔음.',
#    '동 위원은 건설투자의 선행지표인 건축허가면적과 국내 건설수주액이 기성이나 실제 건설투자로 나타나는 데 걸리는 시간을 감안할 때 2003년 3/4분기부터 2004년 3/ 4분기까지 이어진 건축허가면적과 국내 건설수주실적의 마이너스 성장세가 금년 하반 기 건설투자의 부진으로 나타나지는 않을지 물었음.',
#    '이에 대해 관련부서에서는 지난해 3/4분기까지 건설수주실적이 저조했던 데 따 른 영향이 금년 하반기까지 계속되기는 하겠으나 새로운 요인으로서 작년 4/4분기 이 후 건설수주실적이 호전되어 실제 착공으로 이어지고 있는 물량과 정부 종합투자계획 이 플러스 요인으로 작용할 것임을 감안하면 하반기경에는 건설투자가 부진에서 벗어 나 점차 개선될 것으로 보인다고 답변하였음.',
#    '또한 동 위원은 수출물량이 가격요인보다는 해외 수요요인에 의해 주로 결정된 다는 분석결과와 관련하여 동 분석에서 대상으로 한 기간이 환율 변동이 심했던 외환 위기 전후를 포함하고 있는 데다 국제시장에서 동질의 제품끼리 벌이는 치열한 경쟁에 있어서는 가격이 물량에 미치는 영향력이 상당할 것임을 감안할 때 환율 하락이 수출 에 미치는 영향이 과소평가된 것은 아닌지 물었음.',
# ...

# %% [markdown]
# ## 저장/로드

# %%
# import pickle

# mpd_file = data_dir + 'dataframes/mpd_df.pkl'

# with open(mpd_file, 'wb') as f:
#     pickle.dump(mpd_df, f, pickle.HIGHEST_PROTOCOL)

# %%
import pickle

mpd_file = data_dir + 'dataframes/mpd_df.pkl'

with open(mpd_file, 'rb') as f:
    mpd_df = pickle.load(f)

# %%
mpd_df
# Out:
#                                                  title  ...                                        content_sep
# 0    금융통화위원회 의사록(2005년도 제10차)(2...  ...  ([Economic Situation, Foreign Currency, Financ...
# 1                   금융통화위원회 의사록(2005년도 제12차)(2005.6.9)  ...  ([Economic Situation, Foreign Currency, Financ...
# 2                  금융통화위원회 의사록(2005년도 제13차)(2005.6.23)  ...  ([Economic Situation, Foreign Currency, Financ...
# 3                   금융통화위원회 의사록(2005년도 제14차)(2005.7.7)  ...  ([Economic Situation, Foreign Currency, Financ...
# 4                  금융통화위원회 의사록(2005년도 제17차)(2005.8.11)  ...  ([Economic Situation, Foreign Currency, Financ...
# ..                                                 ...  ...                                                ...
# 258               금융통화위원회 의사록(2017년도 제18차)(2017.9.21.)  ...  ([Economic Situation, Foreign Currency, Financ...
# ...

# %%
mpd_df.dtypes
# Out:
# title                  object
# content                object
# time           datetime64[ns]
# content_sep            object
# dtype: object
